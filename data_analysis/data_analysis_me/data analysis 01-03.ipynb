# %%
b = [1, 2, 3]
b

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.random.randn(50).cumsum())

# %%
a = [1, 2, 3]
b = a.copy()
a.append(4)
print(a)
print(b)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3]

# %%
s = 'this\has\no\special\characters'
print(s)
s = r'this\has\no\special\characters'
print(s)
# Out:
# this\has
# o\special\characters
# this\has\no\special\characters

# %%
import bisect
c = [1, 2, 2, 2, 3, 4, 7]
bisect.bisect(c, 2)  # 确认插入值的位置并保证排序
# Out:
# 4

# %%
bisect.bisect(c, 5)
# Out:
# 6

# %%
bisect.insort(c, 6)
c
# Out:
# [1, 2, 2, 2, 3, 4, 6, 7]

# %%
seq1 = ['foo', 'bar', 'baz']
seq2 = ['one', 'two', 'three']
zipped = zip(seq1, seq2)
list(zipped)
# Out:
# [('foo', 'one'), ('bar', 'two'), ('baz', 'three')]

# %%
for i, (a, b) in enumerate(zip(seq1, seq2)):
    print('{0}: {1}, {2}'.format(i, a, b))
# Out:
# 0: foo, one
# 1: bar, two
# 2: baz, three
